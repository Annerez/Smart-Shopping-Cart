# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.3/616.3 kB 9.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !unzip /content/drive/MyDrive/Mask.v4i.yolov8.zip
# Out:
# Archive:  /content/drive/MyDrive/Mask.v4i.yolov8.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/11_jpg.rf.ea13a255d9e73361c835ee8dade28ec1.jpg
#  extracting: test/images/26_jpg.rf.c833dae18662445f52804fb15e4dfe05.jpg
#  extracting: test/images/7_jpg.rf.5986a16d7f5c3947ebba52c6c9762105.jpg
#  extracting: test/images/aW1hZ2UvMjAyMC0wMi9mNzNlY2Y3ZjEyNGNlYmUxYmExNzdhOWJmZjI5NDNkOC5qcGc-_jpg.rf.b17c3aa9dffd22956052b19ae1ae115f.jpg
#  extracting: test/images/couple-of-students-wearing-masks-relaxing-in-the-campus-photo_jpg.rf.3807bbb185e8ed5d7dc31f83bd061611.jpg
#    creating: test/labels/
#  extracting: test/labels/11_jpg.rf.ea13a255d9e73361c835ee8dade28ec1.txt
#  extracting: test/labels/26_jpg.rf.c833dae18662445f52804fb15e4dfe05.txt
#  extracting: test/labels/7_jpg.rf.5986a16d7f5c3947ebba52c6c9762105.txt
# ...

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 73.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 9.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.9 MB/s eta 0:00:00
# ...

# %%
# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=30 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 219MB/s]
# Ultralytics YOLOv8.0.175 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')

# %%
results = model('/content/test/images/11_jpg.rf.ea13a255d9e73361c835ee8dade28ec1.jpg')
# Out:
# image 1/1 /content/test/images/11_jpg.rf.ea13a255d9e73361c835ee8dade28ec1.jpg: 640x640 2 Masks, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
